# %% [markdown]
# <a href="https://colab.research.google.com/github/git-kmoraes/CC7711/blob/main/Lab04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPRegressor

# %%
print('Carregando Arquivo de teste')
arquivo = np.load("/content/teste1.npy")
x = arquivo[0]
y = np.ravel(arquivo[1])

regr = MLPRegressor(hidden_layer_sizes=(100, 100),
                    max_iter=10000,
                    activation='relu', #{'identity', 'logistic', 'tanh', 'relu'},
                    solver='adam',
                    learning_rate = 'adaptive',
                    n_iter_no_change=50)
print('Treinando RNA')
regr = regr.fit(x,y)

print('Preditor')
y_est = regr.predict(x)

media = np.mean(regr.loss_curve_)
dp = np.std(regr.loss_curve_)
print(f"Media = {media:.2f}\n"
      f"Desvio padrao = {dp:.2f}\n")

plt.figure(figsize=[14,7])

#plot curso original
plt.subplot(1,3,1)
plt.plot(x,y)

#plot aprendizagem
plt.subplot(1,3,2)
plt.plot(regr.loss_curve_)

#plot regressor
plt.subplot(1,3,3)
plt.plot(x,y,linewidth=1,color='yellow')
plt.plot(x,y_est,linewidth=2)
# Out:
# Carregando Arquivo de teste
# Treinando RNA
# Preditor
# Media = 0.45
# Desvio padrao = 0.75

# %%
print('Carregando Arquivo de teste')
arquivo = np.load('teste2.npy')
x = arquivo[0]
y = np.ravel(arquivo[1])

regr = MLPRegressor(hidden_layer_sizes=(100, 100),
                    max_iter=10000,
                    activation='relu', #{'identity', 'logistic', 'tanh', 'relu'},
                    solver='adam',
                    learning_rate = 'adaptive',
                    n_iter_no_change=50)
print('Treinando RNA')
regr = regr.fit(x,y)

print('Preditor')
y_est = regr.predict(x)

media = np.mean(regr.loss_curve_)
dp = np.std(regr.loss_curve_)
print(f"Media = {media:.2f}\n"
      f"Desvio padrao = {dp:.2f}\n")

plt.figure(figsize=[14,7])

#plot curso original
plt.subplot(1,3,1)
plt.plot(x,y)

#plot aprendizagem
plt.subplot(1,3,2)
plt.plot(regr.loss_curve_)

#plot regressor
plt.subplot(1,3,3)
plt.plot(x,y,linewidth=1,color='yellow')
plt.plot(x,y_est,linewidth=2)
# Out:
# Carregando Arquivo de teste
# Treinando RNA
# Preditor
# Media = 4.64
# Desvio padrao = 6.53

# %%
print('Carregando Arquivo de teste')
arquivo = np.load('teste3.npy')
x = arquivo[0]
y = np.ravel(arquivo[1])

regr = MLPRegressor(hidden_layer_sizes=(100, 100),
                    max_iter=10000,
                    activation='relu', #{'identity', 'logistic', 'tanh', 'relu'},
                    solver='adam',
                    learning_rate = 'adaptive',
                    n_iter_no_change=50)
print('Treinando RNA')
regr = regr.fit(x,y)

print('Preditor')
y_est = regr.predict(x)

media = np.mean(regr.loss_curve_)
dp = np.std(regr.loss_curve_)
print(f"Media = {media:.2f}\n"
      f"Desvio padrao = {dp:.2f}\n")

plt.figure(figsize=[14,7])

#plot curso original
plt.subplot(1,3,1)
plt.plot(x,y)

#plot aprendizagem
plt.subplot(1,3,2)
plt.plot(regr.loss_curve_)

#plot regressor
plt.subplot(1,3,3)
plt.plot(x,y,linewidth=1,color='yellow')
plt.plot(x,y_est,linewidth=2)
# Out:
# Carregando Arquivo de teste
# Treinando RNA
# Preditor
# Media = 16.07
# Desvio padrao = 29.48

# %%
print('Carregando Arquivo de teste')
arquivo = np.load('teste4.npy')
x = arquivo[0]
y = np.ravel(arquivo[1])

regr = MLPRegressor(hidden_layer_sizes=(100, 100),
                    max_iter=10000,
                    activation='relu', #{'identity', 'logistic', 'tanh', 'relu'},
                    solver='adam',
                    learning_rate = 'adaptive',
                    n_iter_no_change=50)
print('Treinando RNA')
regr = regr.fit(x,y)

print('Preditor')
y_est = regr.predict(x)

plt.figure(figsize=[14,7])

#plot curso original
plt.subplot(1,3,1)
plt.plot(x,y)

#plot aprendizagem
plt.subplot(1,3,2)
plt.plot(regr.loss_curve_)

#plot regressor
plt.subplot(1,3,3)
plt.plot(x,y,linewidth=1,color='yellow')
plt.plot(x,y_est,linewidth=2)
# Out:
# Carregando Arquivo de teste
# Treinando RNA
# Preditor
